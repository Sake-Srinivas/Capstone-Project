# %% [markdown]
# Complex Neural Network

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
import numpy as np
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Dropout

# Specify the encoding when reading the CSV file
df = pd.read_csv('diseases.csv', encoding='latin-1') # or 'cp1252' if 'latin-1' doesn't work

# Feature selection (Symptoms)
X = df[['symptom_1', 'symptom_2', 'symptom_3', 'symptom_4']].fillna('')  # Fill missing symptom columns with empty string if any

# Target selection (Diseases)
y = df['Diseases']

# Encode categorical variables (both symptoms and diseases)
X_encoded = pd.get_dummies(X, columns=['symptom_1', 'symptom_2', 'symptom_3', 'symptom_4'])
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.2, random_state=42)


# Scale the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_encoded)
X_test = scaler.transform(X_test)

model1 = Sequential()
model1.add(Dense(256, input_dim=X_train.shape[1]))  # Increased number of units
model1.add(LeakyReLU(alpha=0.01))
model1.add(Dropout(0.3))  # Adding dropout to prevent overfitting

model1.add(Dense(128))
model1.add(LeakyReLU(alpha=0.01))
model1.add(Dropout(0.3))

model1.add(Dense(64, activation='relu'))
model1.add(Dropout(0.3))

model1.add(Dense(32, activation='relu'))

model1.add(Dense(len(np.unique(y_encoded)), activation='softmax'))

# Compile the model
model1.compile(optimizer=RMSprop(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model1.fit(X_encoded, y_encoded, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
loss, accuracy = model1.evaluate(X_test, y_test, verbose=0)
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.0000e+00 - loss: 4.8228 - val_accuracy: 0.0000e+00 - val_loss: 4.8350
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0277 - loss: 4.8063 - val_accuracy: 0.0000e+00 - val_loss: 4.8430
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0155 - loss: 4.8013 - val_accuracy: 0.0000e+00 - val_loss: 4.8537
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0185 - loss: 4.7899 - val_accuracy: 0.0000e+00 - val_loss: 4.8641
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0216 - loss: 4.7824 - val_accuracy: 0.0000e+00 - val_loss: 4.8788
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0310 - loss: 4.7696 - val_accuracy: 0.0000e+00 - val_loss: 4.8967
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0061 - loss: 4.7508 - val_accuracy: 0.0000e+00 - val_loss: 4.9156
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0000e+00 - loss: 4.7448 - val_accuracy: 0.0000e+00 - val_loss: 4.9420
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0371 - loss: 4.7096 - val_accuracy: 0.0000e+00 - val_loss: 4.9630
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0122 - loss: 4.7037 - val_accuracy: 0.0000e+00 - val_loss: 4.9961
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0557 - loss: 4.6721 - val_accuracy: 0.0000e+00 - val_loss: 5.0377
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0309 - loss: 4.6459 - val_accuracy: 0.0000e+00 - val_loss: 5.0939
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0310 - loss: 4.6225 - val_accuracy: 0.0000e+00 - val_loss: 5.1479
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0371 - loss: 4.5655 - val_accuracy: 0.0000e+00 - val_loss: 5.2321
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0247 - loss: 4.5371 - val_accuracy: 0.0000e+00 - val_loss: 5.3049
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0371 - loss: 4.5008 - val_accuracy: 0.0000e+00 - val_loss: 5.3803
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0154 - loss: 4.4337 - val_accuracy: 0.0000e+00 - val_loss: 5.4705
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0154 - loss: 4.3899 - val_accuracy: 0.0000e+00 - val_loss: 5.5451
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0649 - loss: 4.2956 - val_accuracy: 0.0000e+00 - val_loss: 5.5979
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0277 - loss: 4.3292 - val_accuracy: 0.0000e+00 - val_loss: 5.6970
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0896 - loss: 4.2763 - val_accuracy: 0.0000e+00 - val_loss: 5.8282
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7930 - loss: 0.8562 - val_accuracy: 0.0000e+00 - val_loss: 14.9753
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8325 - loss: 0.8013 - val_accuracy: 0.0000e+00 - val_loss: 14.9698
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8044 - loss: 0.7770 - val_accuracy: 0.0000e+00 - val_loss: 15.1920
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7430 - loss: 0.9212 - val_accuracy: 0.0000e+00 - val_loss: 15.2065
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8243 - loss: 0.7750 - val_accuracy: 0.0000e+00 - val_loss: 15.3721
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8420 - loss: 0.7133 - val_accuracy: 0.0000e+00 - val_loss: 15.6135
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8270 - loss: 0.7729 - val_accuracy: 0.0000e+00 - val_loss: 15.8092
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8133 - loss: 0.8234 - val_accuracy: 0.0000e+00 - val_loss: 15.8333
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8079 - loss: 0.6930 - val_accuracy: 0.0000e+00 - val_loss: 15.8945
# Model Accuracy: 80.00%

# %% [markdown]
# Accuracy Finder

# %%
import pandas as pd

# Load the test data CSV file
test_file_path = 'diseases.csv'  # Replace with your file path
test_df = pd.read_csv(test_file_path, encoding='latin1')

# Assume 'Symptom_1', 'Symptom_2', etc. are the columns in your test data
test_df = pd.get_dummies(test_df, columns=['symptom_1', 'symptom_2', 'symptom_3', 'symptom_4','symptom_5'])

# Align the test data with the training data columns (filling missing columns with 0)
X_test_encoded = test_df.reindex(columns=X_encoded.columns, fill_value=0)
# Standardize the test data using the same scaler as in training
X_test_scaled = scaler.transform(X_test_encoded)

y_pred = model1.predict(X_test_scaled)

# Get the predicted disease classes
y_pred_class = np.argmax(y_pred, axis=1)

# Convert back to disease names
predicted_diseases = le.inverse_transform(y_pred_class)
print(predicted_diseases)
y_true = test_df['Diseases']
accuracy = accuracy_score(y_true, predicted_diseases)
print(f"Model Accuracy on Test Data: {accuracy * 100:.2f}%")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ['Influenza' 'Diabetes Mellitus' 'Hypertension' 'Asthma' 'Chickenpox'
#  'Tuberculosis' 'Hepatitis' 'Heart Disease' 'Arthritis' 'Allergies'
#  'Depression' 'Anxiety Disorders' 'Gastroesophageal Reflux Disease (GERD)'
#  'Stroke' 'Pneumonia' 'Celiac Disease' 'Fibromyalgia' 'Multiple Sclerosis'
#  'Kidney Disease' 'Skin Cancer' 'Lyme Disease' 'Sickle Cell Anemia'
#  'Parkinson\x92s Disease' 'HIV/AIDS' 'Zika Virus' 'Alzheimers Disease'
#  'Chronic Fatigue Syndrome' 'Psoriasis' 'Irritable Bowel Syndrome'
#  'Migraine' 'Anemia' 'Gout' 'Bronchitis' 'Sinusitis' 'Hyperthyroidism'
#  'Hypothyroidism' 'Gallbladder Disease' 'Pancreatitis' 'Meningitis'
#  'Ulcerative Colitis' 'Crohn\x92s Disease' 'Lupus' 'Eczema' 'Pancreatitis'
#  'Deep Vein Thrombosis (DVT)' 'Glaucoma' 'Cataracts'
#  'Retinitis Pigmentosa' 'Macular Degeneration' 'Tetanus' 'Whooping Cough'
#  'Leprosy' 'Ebola Virus Disease' 'Dengue Fever' 'Malaria' 'Cholera'
#  'Rabies' 'Anthrax' 'Legionnaires\x92 Disease' 'Hantavirus'
#  'Toxoplasmosis' 'Shingles' 'Measles' 'Mumps' 'Rubella' 'Typhoid Fever'
#  'Plague' 'Lassa Fever' 'Cystic Fibrosis' 'Hemophilia' 'Scleroderma'
#  'Addison\x92s Disease' 'Cushing\x92s Syndrome' "Graves' Disease"
#  'Osteoporosis' 'Rheumatic Fever' 'Scarlet Fever' 'Marfan Syndrome'
#  'Osteomyelitis' "Wilson's Disease" 'Tinnitus' 'Raynaud\x92s Disease'
#  'Vitiligo' "Bell's Palsy" "Hashimoto's Thyroiditis" "Reye's Syndrome"
#  'Kawasaki Disease' 'Guillain-Barré Syndrome' 'Henoch-Schönlein Purpura'
#  'Pemphigus' 'Ehlers-Danlos Syndrome' "Sjögren's Syndrome"
#  'Goodpasture Syndrome' 'Achalasia' 'Addisonian Crisis' 'Amyloidosis'
#  "Behçet's Disease" 'Chikungunya' 'Myasthenia Gravis' 'Diabetes Mellitus'
#  "Behçet's Disease" 'Addisonian Crisis' 'Crohn\x92s Disease' 'Malaria'
#  'Crohn\x92s Disease' 'Crohn\x92s Disease' 'Pemphigus'
#  'Ehlers-Danlos Syndrome' 'Lassa Fever' 'Alzheimers Disease'
#  'Macular Degeneration' 'Alzheimers Disease' 'Anemia'
#  'Gastroesophageal Reflux Disease (GERD)' 'Hyperthyroidism' 'Hemophilia'
#  'Macular Degeneration' 'Osteomyelitis' 'Toxoplasmosis'
#  'Alzheimers Disease' 'Anemia' "Hashimoto's Thyroiditis"
#  'Myasthenia Gravis' 'Rubella']
# Model Accuracy on Test Data: 79.03%

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize and train RandomForest model
rf_model = RandomForestClassifier(n_estimators=125, random_state=42)
rf_model.fit(X_encoded, y_encoded)

# Evaluate RandomForest on the test set
rf_accuracy = rf_model.score(X_test, y_test)
print(f"RandomForest Model Accuracy: {rf_accuracy * 100:.2f}%")
# Out:
# RandomForest Model Accuracy: 100.00%
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Random Forest with Grid Search

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold  # Import KFold

# Define the hyperparameter grid
param_grid = {
    'n_estimators': [150, 200, 300],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Initialize RandomForest with GridSearch
rf_model = RandomForestClassifier(random_state=42)
# Use KFold instead of StratifiedKFold
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=KFold(n_splits=3), n_jobs=-1, verbose=2)
#cv=3 defaults to StratifiedKFold. Using KFold will create folds without considering class proportions

# Train the model
grid_search.fit(X_encoded, y_encoded)

# Best parameters and accuracy
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_ * 100:.2f}%")

# Evaluate on the test set
y_pred = grid_search.best_estimator_.predict(X_test)
final_accuracy = accuracy_score(y_test, y_pred)
print(f"Final Test Accuracy: {final_accuracy * 100:.2f}%")
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# Best parameters: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# Best accuracy: 0.00%
# Final Test Accuracy: 100.00%
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Feature Selection

# %%
#feature selection:
from sklearn.utils.class_weight import compute_class_weight

# Calculate class weights
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights_dict = dict(enumerate(class_weights))

# Train the neural network with class weights
model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.2, class_weight=class_weights_dict, verbose=1)
# Out:
# Epoch 1/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 0.9618 - loss: 0.1332 - val_accuracy: 0.0000e+00 - val_loss: 11.3757
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.
150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9757 - loss: 0.0721 - val_accuracy: 0.0000e+00 - val_loss: 11.9711
# Epoch 129/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9375 - loss: 0.1696 - val_accuracy: 0.0000e+00 - val_loss: 11.8773
# Epoch 130/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9618 - loss: 0.0851 - val_accuracy: 0.0000e+00 - val_loss: 11.7424
# Epoch 131/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0319 - val_accuracy: 0.0000e+00 - val_loss: 11.8502
# Epoch 132/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.0000e+00 - val_loss: 11.9085
# Epoch 133/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9757 - loss: 0.0589 - val_accuracy: 0.0000e+00 - val_loss: 11.9800
# Epoch 134/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9618 - loss: 0.1393 - val_accuracy: 0.0000e+00 - val_loss: 11.7616
# Epoch 135/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9479 - loss: 0.2316 - val_accuracy: 0.0000e+00 - val_loss: 11.7585
# Epoch 136/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0740 - val_accuracy: 0.0000e+00 - val_loss: 11.7129
# Epoch 137/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9757 - loss: 0.0740 - val_accuracy: 0.0000e+00 - val_loss: 11.7027
# Epoch 138/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9757 - loss: 0.0648 - val_accuracy: 0.0000e+00 - val_loss: 11.7024
# Epoch 139/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9861 - loss: 0.0163 - val_accuracy: 0.0000e+00 - val_loss: 11.7670
# Epoch 140/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0185 - val_accuracy: 0.0000e+00 - val_loss: 11.7864
# Epoch 141/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9618 - loss: 0.1265 - val_accuracy: 0.0000e+00 - val_loss: 11.6975
# Epoch 142/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9757 - loss: 0.0818 - val_accuracy: 0.0000e+00 - val_loss: 11.6845
# Epoch 143/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0324 - val_accuracy: 0.0000e+00 - val_loss: 11.7395
# Epoch 144/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9757 - loss: 0.0563 - val_accuracy: 0.0000e+00 - val_loss: 11.8182
# Epoch 145/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9757 - loss: 0.0469 - val_accuracy: 0.0000e+00 - val_loss: 11.8065
# Epoch 146/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 0.0000e+00 - val_loss: 11.8425
# Epoch 147/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.0000e+00 - val_loss: 11.8968
# Epoch 148/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9618 - loss: 0.1454 - val_accuracy: 0.0000e+00 - val_loss: 11.6824
# Epoch 149/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9861 - loss: 0.0427 - val_accuracy: 0.0000e+00 - val_loss: 11.6306
# Epoch 150/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.0000e+00 - val_loss: 11.6726

# %% [markdown]
# Diseases Prediction

# %%
new_symptoms = ['Wheezing', 'Coughing', 'Chest tightness','Shortness of breath','','']

new_symptoms_df = pd.DataFrame([new_symptoms], columns=['symptom_1', 'symptom_2', 'symptom_3','symptom_4', 'symptom_5', 'symptom_6'])

# Fill any missing symptom columns with empty strings to match the training data
# One-hot encode the new symptoms using the same method as the training data
new_symptoms_encoded = pd.get_dummies(new_symptoms_df, columns=['symptom_1', 'symptom_2', 'symptom_3', 'symptom_4', 'symptom_5', 'symptom_6'])

# Align the new symptoms dataframe with the training encoded dataframe
# This ensures that all the columns used in training are present in the new data (with missing ones filled with 0)
X_new_symptoms = new_symptoms_encoded.reindex(columns=X_encoded.columns, fill_value=0)

# Standardize the new symptoms using the same scaler as the training data
X_new_symptoms_scaled = scaler.transform(X_new_symptoms)

# Predict the disease using the trained model
predicted_class = np.argmax(model.predict(X_new_symptoms_scaled), axis=1)

# Decode the predicted class back to the disease name
predicted_disease = le.inverse_transform(predicted_class)

# Output the predicted disease
print(f"Predicted Disease: {predicted_disease[0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted Disease: Asthma

# %% [markdown]
# Accuracy finder

# %%
import pandas as pd

# Load the test data CSV file
test_file_path = 'diseases.csv'
test_df = pd.read_csv(test_file_path, encoding='latin1')

test_df = pd.get_dummies(test_df, columns=['symptom_1', 'symptom_2', 'symptom_3', 'symptom_4','symptom_5'])
X_test_encoded = test_df.reindex(columns=X_encoded.columns, fill_value=0)
# Standardize the test data using the same scaler as in training
X_test_scaled = scaler.transform(X_test_encoded)

y_pred = grid_search.best_estimator_.predict(X_test_scaled)
predicted_diseases = le.inverse_transform(y_pred)

print(predicted_diseases)
y_true = test_df['Diseases']
accuracy = accuracy_score(y_true, predicted_diseases)
print(f"Model Accuracy on Test Data: {accuracy * 100:.2f}%")
# Out:
# ['Influenza' 'Diabetes Mellitus' 'Hypertension' 'Asthma' 'Chickenpox'
#  'Tuberculosis' 'Hepatitis' 'Heart Disease' 'Arthritis' 'Allergies'
#  'Depression' 'Anxiety Disorders' 'Gastroesophageal Reflux Disease (GERD)'
#  'Stroke' 'Pneumonia' 'Celiac Disease' 'Fibromyalgia' 'Multiple Sclerosis'
#  'Kidney Disease' 'Skin Cancer' 'Lyme Disease' 'Sickle Cell Anemia'
#  'Parkinson\x92s Disease' 'HIV/AIDS' 'Zika Virus' 'Alzheimers Disease'
#  'Chronic Fatigue Syndrome' 'Psoriasis' 'Irritable Bowel Syndrome'
#  'Migraine' 'Anemia' 'Gout' 'Bronchitis' 'Sinusitis' 'Hyperthyroidism'
#  'Hypothyroidism' 'Gallbladder Disease' 'Pancreatitis' 'Meningitis'
#  'Ulcerative Colitis' 'Crohn\x92s Disease' 'Lupus' 'Eczema' 'Pancreatitis'
#  'Deep Vein Thrombosis (DVT)' 'Glaucoma' 'Cataracts'
#  'Retinitis Pigmentosa' 'Macular Degeneration' 'Tetanus' 'Whooping Cough'
#  'Leprosy' 'Ebola Virus Disease' 'Dengue Fever' 'Malaria' 'Cholera'
#  'Rabies' 'Anthrax' 'Legionnaires\x92 Disease' 'Hantavirus'
#  'Toxoplasmosis' 'Shingles' 'Measles' 'Mumps' 'Rubella' 'Typhoid Fever'
#  'Plague' 'Lassa Fever' 'Cystic Fibrosis' 'Hemophilia' 'Scleroderma'
#  'Addison\x92s Disease' 'Cushing\x92s Syndrome' "Graves' Disease"
#  'Osteoporosis' 'Rheumatic Fever' 'Scarlet Fever' 'Marfan Syndrome'
#  'Osteomyelitis' "Wilson's Disease" 'Tinnitus' 'Raynaud\x92s Disease'
#  'Vitiligo' "Bell's Palsy" "Hashimoto's Thyroiditis" "Reye's Syndrome"
#  'Kawasaki Disease' 'Guillain-Barré Syndrome' 'Henoch-Schönlein Purpura'
#  'Pemphigus' 'Ehlers-Danlos Syndrome' "Sjögren's Syndrome"
#  'Goodpasture Syndrome' 'Achalasia' 'Addisonian Crisis' 'Amyloidosis'
#  "Behçet's Disease" 'Chikungunya' 'Myasthenia Gravis' 'Thalassemia'
#  'Scurvy' 'Toxic Shock Syndrome' 'Pheochromocytoma' 'Babesiosis'
#  'Hidradenitis Suppurativa' 'Porphyria' 'Gaucher Disease'
#  'Tay-Sachs Disease' "Huntington's Disease" 'Creutzfeldt-Jakob Disease'
#  'Fragile X Syndrome' 'Turner Syndrome' 'Klinefelter Syndrome'
#  'Angelman Syndrome' 'Prader-Willi Syndrome' 'Dandy-Walker Syndrome'
#  'Von Hippel-Lindau Disease' 'Li-Fraumeni Syndrome' 'Neurofibromatosis'
#  'Carpal Tunnel Syndrome' 'Spina Bifida' 'Hydrocephalus'
#  'Charcot-Marie-Tooth Disease' 'Barrett\x92s Esophagus']
# Model Accuracy on Test Data: 99.19%
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Non Accurate results

# %%
j=0
for i in predicted_diseases:
    if i != y_true[j]:
      print(y_true[j]," ",i)
    j+=1
# Out:
# Diverticulitis   Pancreatitis

# %%
symptom_columns = ['symptom_1', 'symptom_2', 'symptom_3', 'symptom_4', 'symptom_5']

# Combine all symptoms from the symptom columns into a single series
all_symptoms = pd.concat([df[col] for col in symptom_columns])

# Get unique symptoms by removing duplicates
unique_symptoms = all_symptoms.unique()

# Print the unique symptoms
print(unique_symptoms)
print(len(unique_symptoms))
# Out:
# ['Fever' 'Increased thirst' 'Headaches' 'Wheezing' 'Itchy rash' 'Coughing'
#  'Fatigue' 'Chest pain' 'Joint pain' 'Sneezing' 'Persistent sadness'
#  'Excessive worry' 'Heartburn' 'Sudden numbness' 'Cough' 'Diarrhea'
#  'Widespread pain' 'Numbness' 'Swelling' 'New or changing moles'
#  'Pain episodes' 'Tremors' 'Flu-like symptoms' 'Memory loss'
#  'Extreme fatigue' 'Red patches' 'Abdominal pain' 'Severe headache'
#  'Persistent cough' 'Nasal congestion' 'Weight loss' 'Itchy skin'
#  'Leg pain' 'Eye pain' 'Clouded vision' 'Vision loss' 'Blurred vision'
#  'Muscle stiffness' 'Severe cough' 'Skin lesions' 'High fever'
#  'Sore throat' 'Painful rash' 'Swollen salivary glands' 'Rash'
#  'Excessive bleeding' 'Skin tightening' 'Weight gain' 'Anxiety'
#  'Bone fractures' 'Tall stature' 'Bone pain' 'Jaundice'
#  'Ringing in the ears' 'Cold fingers/toes' 'Loss of skin color'
#  'Facial weakness' 'Vomiting' 'Weakness in legs' 'Blisters'
#  'Hypermobile joints' 'Dry eyes' 'Coughing blood' 'Difficulty swallowing'
#  'Severe weakness' 'Mouth ulcers' 'Muscle weakness' 'High blood pressure'
#  'Painful lumps under skin' 'Enlarged spleen' 'Uncontrolled movements'
#  'Learning disabilities' 'Short stature' 'Delayed puberty'
#  'Developmental delays' 'Constant hunger' 'Skin tumors' 'Numbness in hand'
#  'Back pain' 'Enlarged head' ' Body aches' 'Frequent urination'
#  'Shortness of breath' 'Stiffness' 'Itching' 'Restlessness'
#  'Regurgitation' 'Confusion' 'Bloating' 'Vision problems' 'Headache'
#  'Dry skin' 'Nausea' 'Weakness' 'Redness' 'Mucus production' 'Facial pain'
#  'Rapid heartbeat' 'Stiff neck' 'Sensitivity to light' 'Night blindness'
#  'Difficulty reading' 'Jaw cramping' 'Vomiting after coughing'
#  'Numbness in limbs' 'Severe headaches' 'Chills' 'Muscle aches'
#  'Muscle pain' 'Swollen lymph nodes' 'Lung infections'
#  'Fatty deposits around the face' 'Loss of height' 'Long limbs'
#  'Hearing loss' 'Numbness in extremities' 'Premature graying of hair'
#  'Drooping of one side' 'Lethargy' 'Red eyes' 'Difficulty walking'
#  'Mouth sores' 'Soft skin' 'Dry mouth' 'Low blood pressure' 'Swollen legs'
#  'Genital sores' 'Drooping eyelids' 'Pale skin' 'Swollen gums' 'Sweating'
#  'Swollen areas' 'Sensitivity to sunlight' 'Loss of motor skills'
#  'Cognitive decline' 'Speech delays' 'Breast development' 'Lack of speech'
#  'Obesity' 'Dizziness' 'Easy bruising' 'Freckles in armpit area'
#  'Tingling fingers' 'Foot drop' 'Nosebleeds' 'Chest tightness'
#  'Night sweats' 'Runny nose' 'Loss of interest' 'Difficulty concentrating'
#  'Trouble speaking' 'Difficulty breathing' 'Sleep disturbances'
#  'Changes in urine output' 'Bleeding' 'Slow movement'
#  'Difficulty in problem-solving' 'Cold intolerance' 'Blood in stool'
#  'Skin rash' 'Halos around lights' 'Difficulty seeing at night'
#  'Tunnel vision' 'Distorted vision' 'Sweats' 'Dehydration'
#  'Excessive salivation' 'Tingling sensation' 'Stomach pain'
#  'Bruising easily' 'Acid reflux' 'Thin skin' 'Heart murmurs'
#  'Slurred speech' 'Ear pain' 'Color changes in skin'
#  'Difficulty closing eye' 'Depression' 'Tingling in extremities'
#  'Skin peeling' 'Eye inflammation' 'Bruising' 'Skin infections' 'Seizures'
#  'Behavioral issues' 'Heart defects' 'Low muscle mass'
#  'Delayed development' 'Bone deformities' 'Weak grip'
#  'Loss of bladder control' 'Loss of sensation' nan 'Loss of appetite'
#  'Dark urine' 'Palpitations' 'Reduced range of motion' 'Hives'
#  'Coordination issues' 'Sores' 'Characteristic rash' 'Frequent infections'
#  'Balance issues' 'Conjunctivitis' 'Personality changes'
#  'Unrefreshing sleep' 'Burning sensation' 'Constipation'
#  'Chest discomfort' 'Irritability' 'Indigestion' 'Warmth in affected area'
#  'Fading colors' 'Sensitivity to bright lights' 'Dark spots in vision'
#  'Muscle spasms' 'Eye problems' 'Unexplained bleeding' 'Leg cramps'
#  'Agitation' 'Skin ulcers' 'Poor growth' 'Prolonged bleeding'
#  'Darkening of the skin' 'Stooped posture' 'Red tongue' 'Curved spine'
#  'Pain in affected areas' 'Patchy skin discoloration' 'Altered taste'
#  'Sensitivity to cold' 'Rash on hands and feet' 'Blood in urine'
#  'Painful skin' 'Stretchy skin' 'Kidney problems' 'Irregular heartbeat'
#  'Scarring' 'Red or brown urine' 'Blindness' 'Hallucinations' 'Large ears'
#  'Webbed neck' 'Frequent laughter' 'Poor coordination' 'Tumors'
#  'Tumor formation' 'Pain in wrist' 'Visible gap in spine' 'Poor balance'
#  'High arches in feet' 'Vomiting blood']
# 252
